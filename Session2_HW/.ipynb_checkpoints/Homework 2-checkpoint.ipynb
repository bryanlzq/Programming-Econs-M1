# %%
# Origin: Homework for week 2 of programming class
# Author: Bryan Lim
# Title: Homework 2.ipynb
# Last modified: 2016.09.22

# %%
w0 <- 100 
p <- runif(1) 
T <- 10  

w <- rep(0, T+1)
x <- rep(0, T)

sprintf("Probability of winning %s", p)
sprintf("You started with $%s", w0)

w[1] = w0

for(t in 1:T){
    u <- runif(1)
    if(u <= 1 - p){
        print("You LOSE!")
        w[t+1] <- w[t] - 1
    }else{
        print("You WIN!")
        w[t+1] <- w[t] + 1
    }
    print(sprintf("Now you've got $%s.", w[t+1]))
}

time = 0:T
plot(time, w, "l")
# Out:
# [1] "Probability of winning 0.705519027542323"
# [1] "You started with $100"
# [1] "You WIN!"
# [1] "Now you've got $101."
# [1] "You LOSE!"
# [1] "Now you've got $100."
# [1] "You WIN!"
# [1] "Now you've got $101."
# [1] "You WIN!"
# [1] "Now you've got $102."
# [1] "You WIN!"
# [1] "Now you've got $103."
# [1] "You LOSE!"
# [1] "Now you've got $102."
# [1] "You WIN!"
# [1] "Now you've got $103."
# [1] "You WIN!"
# [1] "Now you've got $104."
# [1] "You WIN!"
# [1] "Now you've got $105."
# [1] "You LOSE!"
# [1] "Now you've got $104."
# plot without title

# %%
w0 <- 100 
p <- runif(1) 
T <- 10  

w <- rep(0, T+1)
x <- rep(0, T)

sprintf("Probability of winning %s", p)
sprintf("You started with $%s", w0)

w[1] = w0

for(t in 1:T){
    u <- 0.5
    if(u <= 1 - p){
        print("You LOSE!")
        w[t+1] <- w[t] - 1
    }else{
        print("You WIN!")
        w[t+1] <- w[t] + 1
    }
    print(sprintf("Now you've got $%s.", w[t+1]))
}

time = 0:T
plot(time, w, "l")
# Out:
# [1] "Probability of winning 0.762002374744043"
# [1] "You started with $100"
# [1] "You WIN!"
# [1] "Now you've got $101."
# [1] "You WIN!"
# [1] "Now you've got $102."
# [1] "You WIN!"
# [1] "Now you've got $103."
# [1] "You WIN!"
# [1] "Now you've got $104."
# [1] "You WIN!"
# [1] "Now you've got $105."
# [1] "You WIN!"
# [1] "Now you've got $106."
# [1] "You WIN!"
# [1] "Now you've got $107."
# [1] "You WIN!"
# [1] "Now you've got $108."
# [1] "You WIN!"
# [1] "Now you've got $109."
# [1] "You WIN!"
# [1] "Now you've got $110."
# plot without title

# %%
w0 <- 100
M <- 10000
R <- 100
 
K <- c(0, R)

w <- rep(0, T+1)
x <- rep(0, T)

w[1] = w0

p <- runif(1,0,1) 

for(j in 1:R){
    w <- rep(0, M+1) 
    w[1] <- w0
    for (i in 1:M){ 
        s <- runif(1,0,1) 
        if(s<=p){
            w[i+1] <- w[i] + 1 
        } else {
            w[i+1] <- w[i] - 1  
        }
    } 
    u[j] <- w[M+1] 
} 

average <- mean(u) 
average
# Out:
# [1] -4537.06

# %%
w0 <- 100
M <- 10000
R <- 100

b <- c(0, R)

w <- rep(0, T+1)
x <- rep(0, T)

w[1] = w0

for(j in 1:R){
    p <- runif(1,0,1) 
    w <- rep(0, M+1)
    w[1] <- w0
    
    for (i in 1:M){
        s <- runif(1,0,1) 
        
        if(s<=p){
            w[i+1] <- w[i] + 1 
        } else {
            w[i+1] <- w[i] - 1
        }
    }
    b[j] <- w[M+1]
} 

ave <- mean(b) 
ave
# Out:
# [1] 665.12
